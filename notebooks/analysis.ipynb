# %% [markdown]
# # Uncertainty vs. Explainability Consistency Analysis\nComputes inter-client cosine similarity and performs Pearson/Spearman correlation with MC Dropout uncertainty.\n

# %%
import pandas as pd\ncorr_df = pd.read_csv('../results/correlation_results.csv')\ncorr_df.head()
