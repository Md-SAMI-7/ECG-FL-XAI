# %% [markdown]
# # 1D Grad-CAM Explainability\nComputes and plots 1D lead-wise and temporal Grad-CAM activation heatmaps on ECG beats.\n

# %%
import numpy as np\nimport matplotlib.pyplot as plt\n# Visualizing sample Grad-CAM heatmap\nprint('Grad-CAM pipeline ready.')
