# %% [markdown]
# # Federated Learning Training & Convergence\nEvaluates multi-round federated training across FedAvg, FedProx, and FedAdam across 5 hospital partitions.\n

# %%
import torch\nfrom models.resnet34_1d import ResNet1D34\nmodel = ResNet1D34(12, 12)\nprint('Model initialized:', model)
